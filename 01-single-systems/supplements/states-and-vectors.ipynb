# %% [markdown]
# # Lesson 1: States, Vectors, and Basic Operations
#
# This notebook explores fundamental quantum states, matrix-vector multiplications using NumPy, probabilistic measurements via Qiskit's `Statevector` class, and basic single-qubit quantum circuits.

# %%
from qiskit import __version__
import numpy as np
from qiskit.quantum_info import Statevector, Operator
from qiskit.visualization import array_to_latex, plot_histogram
from qiskit import QuantumCircuit

print(f"Active Qiskit Version: {__version__}")

# %%
# Define standard computational basis vectors
ket0 = np.array([[1], [0]])
ket1 = np.array([[0], [1]])

# Construct a custom superposition operator
M1 = np.array([[1, 1], [0, 0]])
M2 = np.array([[1, 0], [0, 1]])
custom_operator = M1 / 2 + M2 / 2

# Perform matrix-vector multiplication
result_state = custom_operator @ ket1
display(array_to_latex(result_state))
